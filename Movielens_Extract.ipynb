# %%
import pandas as pd
file_dir = 'C:/Users/Yasmin/Desktop/Data_Analytics_Bootcamp/Class_Material'

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection  budget  \
# 8731   False                   NaN       0
# 41313  False                   NaN       0
# 8735   False                   NaN       0
# 5340   False                   NaN  100000
# 18621  False                   NaN       0
#
#                                                   genres  \
# 8731                       [{'id': 18, 'name': 'Drama'}]
# 41313                      [{'id': 18, 'name': 'Drama'}]
# 8735   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 5340   [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 18621  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
#
#                                    homepage     id    imdb_id  \
# 8731                                    NaN   8327  tt0071615
# 41313                                   NaN  41914  tt0119608
# 8735                                    NaN  29859  tt0072608
# 5340                                    NaN   1842  tt0068837
# 18621  http://www.teamstarkid.com/avpm.html  54507  tt2033193
#
#       original_language                                     original_title  \
# 8731                 en                                  The Holy Mountain
# 41313                cs                                         Mandragora
# 8735                 en  The Adventure of Sherlock Holmes' Smarter Brother
# 5340                 en                          The Legend of Boggy Creek
# 18621                en                              A Very Potter Musical
#
#                                                 overview  ... release_date  \
# 8731   A Mexican master leads a Christ figure and oth...  ...   1973-05-01
# 41313  Marek is a 15-year-old from a provincial villa...  ...   1997-10-23
# 8735   After spending decades living in the shadow of...  ...   1975-01-01
# 5340   A documentary-style drama based on true accoun...  ...   1972-08-01
# 18621  In April 2009, a group of University of Michig...  ...   2009-04-09
#
#           revenue runtime                                   spoken_languages  \
# 8731          0.0   114.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 41313         0.0   126.0             [{'iso_639_1': 'cs', 'name': 'Český'}]
# 8735          0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5340   22000000.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18621         0.0   166.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 8731   Released                                                NaN
# 41313  Released  He was 15 – an innocent from a small village, ...
# 8735   Released                                                NaN
# 5340   Released                                      A True Story.
# 18621  Released                             The awesomeness begins
#
#                                                    title  video vote_average  \
# 8731                                   The Holy Mountain  False          7.7
# 41313                                         Mandragora  False          6.0
# 8735   The Adventure of Sherlock Holmes' Smarter Brother  False          6.1
# 5340                           The Legend of Boggy Creek  False          5.6
# 18621                              A Very Potter Musical   True          7.7
#
#       vote_count
# 8731       143.0
# 41313        7.0
# 8735        47.0
# 5340        19.0
# 18621       20.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 12941553  134387     3386     4.5  1446082467
# 22336527  231841     3735     4.0  1167870870
# 18758543  194801      477     3.0   854171521
# 14241184  147868     3000     5.0  1351118630
# 22205207  230451      370     2.0  1173205052
